# %% [markdown]
# # Predicting Risk of Heart Disease with KNN Classification Model

# %% [markdown]
# The Swedish CARdioPulmonary Bioimage Study (SCAPIS) found that more than 40% of the middle aged adults studied had a coronary artery disease without their knowledge. According to the government of Canada, heart disease is the second leading cause of death among Canadians. Thus, being able to identify the presence of a heart condition as early as possible is incredibly important in the medical field. In this project, we ask:Can we predict whether a patient is suffering from a heart disease based on their medical history? In order to answer this question, we will build a classification model using 4 datasets sourced from The UCI Machine Learning Repository. These datasets were created by The Hungarian Institute of Cariology, The University Hospitals in Basel and Zurich Switzerland, as well as The V.A Medical Center, Long Beach and Cleveland Clinic Foundation. Each dataset has 14 columns that represent different types of patient information and were combined to create a much larger dataset composed of data from all 4 sources with 997 rows and 15 columns (extra column added to indicate where row was sourced from). The other columns in our dataset are as follows:
#
# 1. age : age of the individual (years).
#
# 2. sex : gender of the individual 1 = male 0 = female
#
# 3. type : type of chest-pain experienced by the individual
# (1 = typical angina, 2 = atypical angina, 3 = non anginal pain, 4 = asymptotic)
#
# 4. rbp : resting blood pressure value of an individual (in mmHg)
#
# 5. chol : serum cholesterol (mg/dl unit)
#
# 6. fbs: compares the fasting blood sugar value of an individual with 120mg/dl. If fasting blood sugar > 120mg/dl then : 1 (true), else : 0 (false)
#
# 7. rECG : resting electrocardiographic results
# (0 = normal, 1 = having ST-T wave abnormality, 2 = left ventricular hyperthrophy)
#
# 8. thalach : max heart rate achieved by an individual.
#
# 9. excr_ang : exercise induced angina
# (1 = yes. 0 = no)
#
# 10. old_pk : ST depression induced by exercise relative to rest: displays the value which is an integer or float.
#
# 11. slope : peak exercise ST segment : 1 = upsloping 2 = flat 3 = downsloping
#
# 12. ca : number of major vessels (0–3) colored by flourosopy : integer or float.
#
# 13. thal : thalassemia : 3 = normal 6 = fixed defect 7 = reversible defect
#
# 14. disease: is the condition present? (angiographic disease status)
# Value 0: < 50% diameter narrowing-> false
# Value 1: > 50% diameter narrowing-> true

# %%
#Load necessary packages
library(plyr)
library(tidyverse)
library(testthat)
library(digest)
library(repr)
library(tidymodels)
library(ggplot2)
library("gridExtra")
library(GGally)
library(ggplot2)

# %%
#read and wrangle data

#cleveland data
cleveland<-read_delim("https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data",
                col_name=FALSE)|>
mutate(source="cleveland")
colnames(cleveland)<-c("age","sex","type","rbp","cholesterol","fbs","rECG","thalach","excr_ang","old_pk","slope","ca","thal","disease","source")
cleveland$disease<-ifelse(cleveland$disease==0, "true","false")


#hungary data
hungary<-read_delim("https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/reprocessed.hungarian.data",
                col_name = FALSE)|>
mutate(source="hungary")
colnames(hungary)<-c("age","sex","type","rbp","cholesterol","fbs","rECG","thalach","excr_ang","old_pk","slope","ca","thal","disease","source")
hungary$disease<-ifelse(hungary$disease==0, "true","false")

#long beach data
va<-read_delim("https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.va.data",
                col_name=FALSE)|>
mutate(source="va")
colnames(va)<-c("age","sex","type","rbp","cholesterol","fbs","rECG","thalach","excr_ang","old_pk","slope","ca","thal","disease","source")
va$disease<-ifelse(va$disease==0, "true","false")

#switzerland data
swtz<-read_delim("https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.va.data",
                col_name=FALSE)|>
mutate(source="swtz")
colnames(swtz)<-c("age","sex","type","rbp","cholesterol","fbs","rECG","thalach","excr_ang","old_pk","slope","ca","thal","disease","source")
swtz$disease<-ifelse(swtz$disease==0, "true","false")


#combine into one database

heart_data_OG<-rbind(va,hungary,cleveland,swtz)


heart_data_OG
# Out:
# Rows: 303 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (2): X12, X13
# dbl (12): X1, X2, X3, X4, X5, X6, X7, X8, X9, X10, X11, X14
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 294 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: " "
# dbl (14): X1, X2, X3, X4, X5, X6, X7, X8, X9, X10, X11, X12, X13, X14
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 200 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (9): X4, X5, X6, X8, X9, X10, X11, X12, X13
# dbl (5): X1, X2, X3, X7, X14
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 200 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (9): X4, X5, X6, X8, X9, X10, X11, X12, X13
# dbl (5): X1, X2, X3, X7, X14
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     age sex type rbp cholesterol fbs rECG thalach excr_ang old_pk slope ca thal
# 1   63  1   4    140 260         0   1    112     1        3      2     ?  ?
# 2   44  1   4    130 209         0   1    127     0        0      ?     ?  ?
# 3   60  1   4    132 218         0   1    140     1        1.5    3     ?  ?
# 4   55  1   4    142 228         0   1    149     1        2.5    1     ?  ?
# 5   66  1   3    110 213         1   2    99      1        1.3    2     ?  ?
# 6   66  1   3    120 0           0   1    120     0        -0.5   1     ?  ?
# 7   65  1   4    150 236         1   1    105     1        0      ?     ?  ?
# 8   60  1   3    180 0           0   1    140     1        1.5    2     ?  ?
# 9   60  1   3    120 0           ?   0    141     1        2      1     ?  ?
# 10  60  1   2    160 267         1   1    157     0        0.5    2     ?  ?
# 11  56  1   2    126 166         0   1    140     0        0      ?     ?  ?
# 12  59  1   4    140 0           0   1    117     1        1      2     ?  ?
# 13  62  1   4    110 0           0   0    120     1        0.5    2     ?  3
# 14  63  1   3    ?   0           0   2    ?       ?        ?      ?     ?  ?
# 15  57  1   4    128 0           1   1    148     1        1      2     ?  ?
# 16  62  1   4    120 220         0   1    86      0        0      ?     ?  ?
# 17  63  1   4    170 177         0   0    84      1        2.5    3     ?  ?
# 18  46  1   4    110 236         0   0    125     1        2      2     ?  ?
# 19  63  1   4    126 0           0   1    120     0        1.5    3     ?  ?
# 20  60  1   4    152 0           0   1    118     1        0      ?     ?  7
# 21  58  1   4    116 0           0   0    124     0        1      1     ?  ?
# 22  64  1   4    120 0           1   1    106     0        2      2     ?  ?
# 23  63  1   3    130 0           0   1    111     1        0      ?     ?  ?
# 24  74  1   3    ?   0           0   0    ?       ?        ?      ?     ?  ?
# 25  52  1   3    128 0           0   1    180     0        3      1     ?  ?
# 26  69  1   4    130 0           1   1    129     0        1      2     ?  6
# 27  51  1   4    ?   0           1   1    ?       ?        ?      ?     ?  ?
# 28  60  1   4    130 186         1   1    140     1        0.5    2     ?  ?
# 29  56  1   4    120 100         0   0    120     1        1.5    2     0  7
# 30  55  1   3    ?   228         0   1    ?       ?        ?      ?     ?  ?
# ⋮   ⋮   ⋮   ⋮    ⋮   ⋮           ⋮   ⋮    ⋮       ⋮        ⋮      ⋮     ⋮  ⋮
# 968 53  1   4    124 243         0   0    122     1        2      2     ?  7
# 969 37  1   3    118 240         0   2    165     0        1      2     ?  3
# 970 67  1   4    140 219         0   1    122     1        2      2     ?  7
# 971 74  1   3    140 237         1   0    94      0        0      ?     ?  ?
# 972 63  1   2    ?   165         0   1    ?       ?        ?      ?     ?  ?
# 973 58  1   4    100 213         0   1    110     0        0      ?     ?  ?
# 974 61  1   4    190 287         1   2    150     1        2      3     ?  ?
# 975 64  1   4    130 258         1   2    130     0        0      ?     ?  6
# 976 58  1   4    160 256         1   2    113     1        1      1     ?  ?
# 977 60  1   4    130 186         1   2    140     1        0.5    2     ?  ?
# 978 57  1   4    122 264         0   2    100     0        0      ?     ?  ?
# 979 55  1   3    ?   ?           0   1    ?       ?        ?      ?     ?  ?
# 980 55  1   4    120 226         0   2    127     1        1.7    3     ?  7
# 981 56  1   4    130 203         1   0    98      0        1.5    2     ?  7
# 982 57  1   4    130 207         0   1    96      1        1      2     ?  ?
# 983 61  1   3    ?   284         0   0    ?       ?        ?      ?     ?  ?
# 984 61  1   3    120 337         0   0    98      1        0      ?     ?  ?
# 985 58  1   3    150 219         0   1    118     1        0      ?     ?  ?
# 986 74  1   4    155 310         0   0    112     1        1.5    3     ?  ?
# 987 68  1   3    134 254         1   0    151     1        0      ?     ?  3
# 988 51  0   4    114 258         1   2    96      0        1      1     ?  ?
# 989 62  1   4    160 254         1   1    108     1        3      2     ?  ?
# 990 53  1   4    144 300         1   1    128     1        1.5    2     ?  ?
# 991 62  1   4    158 170         0   1    138     1        0      ?     ?  ?
# 992 46  1   4    134 310         0   0    126     0        0      ?     ?  3
# 993 54  0   4    127 333         1   1    154     0        0      ?     ?  ?
# 994 62  1   1    ?   139         0   1    ?       ?        ?      ?     ?  ?
# 995 55  1   4    122 223         1   1    100     0        0      ?     ?  6
# 996 58  1   4    ?   385         1   2    ?       ?        ?      ?     ?  ?
# 997 62  1   2    120 254         0   2    93      1        0      ?     ?  ?
#     disease source
# 1   false   va
# 2   true    va
# 3   false   va
# 4   false   va
# 5   true    va
# 6   true    va
# 7   false   va
# 8   true    va
# 9   false   va
# 10  false   va
# 11  true    va
# 12  false   va
# 13  false   va
# 14  false   va
# 15  false   va
# 16  true    va
# 17  false   va
# 18  false   va
# 19  true    va
# 20  true    va
# 21  false   va
# 22  false   va
# 23  false   va
# 24  true    va
# 25  false   va
# 26  false   va
# 27  false   va
# 28  false   va
# 29  false   va
# 30  false   va
# ⋮   ⋮       ⋮
# 968 false   swtz
# 969 true    swtz
# 970 false   swtz
# 971 false   swtz
# 972 true    swtz
# 973 true    swtz
# 974 false   swtz
# 975 false   swtz
# 976 false   swtz
# 977 false   swtz
# 978 false   swtz
# 979 true    swtz
# 980 false   swtz
# 981 false   swtz
# 982 true    swtz
# 983 false   swtz
# 984 false   swtz
# 985 false   swtz
# 986 false   swtz
# 987 true    swtz
# 988 true    swtz
# 989 false   swtz
# 990 false   swtz
# 991 false   swtz
# 992 false   swtz
# 993 false   swtz
# 994 true    swtz
# 995 false   swtz
# 996 true    swtz
# 997 false   swtz

# %% [markdown]
# Now that the dataset has been compiled and read, we can tidy it to remove any missing values, change the class of variables to allow for classification, and select the relevant predicting variables.

# %%
#tidy data

heart_data<-heart_data_OG|>
select(source, disease, age, sex, rbp,thalach, type, cholesterol)|>
filter(type!="?",
       sex!="?",
       rbp!="?",
       cholesterol!="NA",
       cholesterol!="0",
       rbp!="0",
      thalach!="?")|>
mutate(sex=as.numeric(sex),
      rbp=as.numeric(rbp),
       disease=as.factor(disease),
        thalach=as.numeric(thalach),
      cholesterol=as.numeric(cholesterol)
      )|>
na.omit()

heart_data
# Out:
# Warning message in mask$eval_all_mutate(quo):
# “NAs introduced by coercion”
#     source disease age sex rbp thalach type cholesterol
# 1   va     false   63  1   140 112     4    260
# 2   va     true    44  1   130 127     4    209
# 3   va     false   60  1   132 140     4    218
# 4   va     false   55  1   142 149     4    228
# 5   va     true    66  1   110  99     3    213
# 6   va     false   65  1   150 105     4    236
# 7   va     false   60  1   160 157     2    267
# 8   va     true    56  1   126 140     2    166
# 9   va     true    62  1   120  86     4    220
# 10  va     false   63  1   170  84     4    177
# 11  va     false   46  1   110 125     4    236
# 12  va     false   60  1   130 140     4    186
# 13  va     false   56  1   120 120     4    100
# 14  va     false   77  1   124 110     4    171
# 15  va     false   63  1   160 105     4    230
# 16  va     false   59  1   122 117     4    233
# 17  va     true    42  1   134 160     3    240
# 18  va     false   62  1   152  97     4    153
# 19  va     true    56  1   124 161     2    224
# 20  va     false   57  1   130 148     4    311
# 21  va     false   67  1   142 125     1    270
# 22  va     true    55  1   110 180     2    214
# 23  va     false   57  1   140 144     4    214
# 24  va     false   54  1   136 140     4    220
# 25  va     false   72  1   120 102     3    214
# 26  va     false   75  1   170 108     4    203
# 27  va     false   60  1   142 110     4    216
# 28  va     false   64  0   142 140     4    276
# 29  va     true    58  1   132  69     4    458
# 30  va     false   61  1   146 148     4    241
# ⋮   ⋮      ⋮       ⋮   ⋮   ⋮   ⋮       ⋮    ⋮
# 772 swtz   false   56  1   128 119     4    223
# 773 swtz   false   64  1   150 135     4    193
# 774 swtz   false   57  1   156 119     4    173
# 775 swtz   false   69  1   122  84     4    216
# 776 swtz   false   57  1   180 120     2    285
# 777 swtz   false   53  1   124 122     4    243
# 778 swtz   true    37  1   118 165     3    240
# 779 swtz   false   67  1   140 122     4    219
# 780 swtz   false   74  1   140  94     3    237
# 781 swtz   true    58  1   100 110     4    213
# 782 swtz   false   61  1   190 150     4    287
# 783 swtz   false   64  1   130 130     4    258
# 784 swtz   false   58  1   160 113     4    256
# 785 swtz   false   60  1   130 140     4    186
# 786 swtz   false   57  1   122 100     4    264
# 787 swtz   false   55  1   120 127     4    226
# 788 swtz   false   56  1   130  98     4    203
# 789 swtz   true    57  1   130  96     4    207
# 790 swtz   false   61  1   120  98     3    337
# 791 swtz   false   58  1   150 118     3    219
# 792 swtz   false   74  1   155 112     4    310
# 793 swtz   true    68  1   134 151     3    254
# 794 swtz   true    51  0   114  96     4    258
# 795 swtz   false   62  1   160 108     4    254
# 796 swtz   false   53  1   144 128     4    300
# 797 swtz   false   62  1   158 138     4    170
# 798 swtz   false   46  1   134 126     4    310
# 799 swtz   false   54  0   127 154     4    333
# 800 swtz   false   55  1   122 100     4    223
# 801 swtz   false   62  1   120  93     2    254

# %% [markdown]
# The data was split into a training and a testing set. The training set, containing 75% of our data, will be used to build and teach the model. The testing set, containing 25% of our data, will remain untouched during the model contruction and will only be used to test the model's accuracy after it has been built.

# %%
#Split the data
set.seed(4321) 
heart_splt <- initial_split(heart_data, prop = 0.75
                           , strata =disease)
heart_train <- training(heart_splt)
heart_test<- testing(heart_splt)
heart_train
# Out:
#     source    disease age sex rbp thalach type cholesterol
# 1   va        false   63  1   140 112     4    260
# 2   va        false   60  1   132 140     4    218
# 3   va        false   55  1   142 149     4    228
# 4   va        false   65  1   150 105     4    236
# 5   va        false   60  1   160 157     2    267
# 6   va        false   63  1   170  84     4    177
# 7   va        false   46  1   110 125     4    236
# 8   va        false   60  1   130 140     4    186
# 9   va        false   56  1   120 120     4    100
# 10  va        false   77  1   124 110     4    171
# 11  va        false   63  1   160 105     4    230
# 12  va        false   62  1   152  97     4    153
# 13  va        false   67  1   142 125     1    270
# 14  va        false   57  1   140 144     4    214
# 15  va        false   54  1   136 140     4    220
# 16  va        false   72  1   120 102     3    214
# 17  va        false   75  1   170 108     4    203
# 18  va        false   60  1   142 110     4    216
# 19  va        false   61  1   146 148     4    241
# 20  va        false   62  1   135 130     4    297
# 21  va        false   63  1   130 138     4    308
# 22  va        false   62  1   158 112     4    210
# 23  va        false   75  1   136 112     4    225
# 24  va        false   63  1   160  88     4    267
# 25  va        false   62  1   112 150     1    258
# 26  va        false   68  1   150 132     3    195
# 27  va        false   65  1   150 120     4    235
# 28  va        false   63  1    96 121     4    305
# 29  va        false   61  1   120 135     4    282
# 30  va        false   50  1   144 120     4    349
# ⋮   ⋮         ⋮       ⋮   ⋮   ⋮   ⋮       ⋮    ⋮
# 571 cleveland true    42  1   130 150     3    180
# 572 cleveland true    66  1   160 138     4    228
# 573 cleveland true    64  1   170 155     1    227
# 574 cleveland true    66  0   146 152     3    278
# 575 cleveland true    39  0   138 152     3    220
# 576 cleveland true    58  0   130 131     4    197
# 577 cleveland true    47  1   130 179     3    253
# 578 cleveland true    35  1   122 174     2    192
# 579 cleveland true    58  1   125 144     2    220
# 580 cleveland true    56  1   130 163     2    221
# 581 cleveland true    56  1   120 169     2    240
# 582 swtz      true    44  1   130 127     4    209
# 583 swtz      true    66  1   110  99     3    213
# 584 swtz      true    56  1   126 140     2    166
# 585 swtz      true    62  1   120  86     4    220
# 586 swtz      true    56  1   124 161     2    224
# 587 swtz      true    55  1   110 180     2    214
# 588 swtz      true    58  1   132  69     4    458
# 589 swtz      true    40  1   106  80     3    240
# 590 swtz      true    64  1   130 128     4    223
# 591 swtz      true    55  1   150 150     4    160
# 592 swtz      true    57  1   110 100     4    197
# 593 swtz      true    61  0   140 120     2    298
# 594 swtz      true    62  1   120  86     3    220
# 595 swtz      true    53  1   155 160     3    175
# 596 swtz      true    59  1   140 154     4    274
# 597 swtz      true    41  1   150 128     4    171
# 598 swtz      true    58  1   100 110     4    213
# 599 swtz      true    57  1   130  96     4    207
# 600 swtz      true    51  0   114  96     4    258

# %% [markdown]
# We can verify that the data was split by inspecting the training set specifications. Our training set has 600 rows, which is approximately 75% of our original dataset, indicating that the split was successful.

# %% [markdown]
# ## Preliminary Data Analysis

# %% [markdown]
# Once the training set was created, we first checked if there were any rows with missing data for any of the variables.

# %%
# Check if there are any rows with missing data
print("Table 1: Number of Rows with Missing Data for the Predictor and Classifier Variables")
heart_missing <- map_df(heart_train, ~sum(is.na(.)))
heart_missing
# Out:
# [1] "Table 1: Number of Rows with Missing Data for the Predictor and Classifier Variables"
#   source disease age sex rbp thalach type cholesterol
# 1 0      0       0   0   0   0       0    0

# %% [markdown]
# The next step is checking the number of observations that both the training set and the orgininal have for each class label. This is to check that both data sets have the same ratio between the class labels. We also want to make sure that the distrobution of class labels in the dataset is equal, since unequal distrobution can lead to inaccurate predictions.

# %%
print("Table 2.1: Number of Observations for the Predictor and Class Labels-Training Set")
num_obs <- nrow(heart_train) 
heart_train|>
group_by(disease)|>
summarize(n = n(),
            percentage = n() / num_obs * 100) 
print("Table 2.2: Number of Observations for the Predictor and Class Labels-Original Data")
num_obs <- nrow(heart_data) 
heart_data|>
group_by(disease)|>
summarize(n = n(),
            percentage = n() / num_obs * 100)
# Out:
# [1] "Table 2.1: Number of Observations for the Predictor and Class Labels-Training Set"
#   disease n   percentage
# 1 false   302 50.33333
# 2 true    298 49.66667
# [1] "Table 2.2: Number of Observations for the Predictor and Class Labels-Original Data"
#   disease n   percentage
# 1 false   403 50.31211
# 2 true    398 49.68789

# %%
#check that there are no nosensical zeros
rbp_zero<-sum(heart_train$rbp == "0")
print("Number of rbp Observations Equal to Zero")
rbp_zero


thal_zero<-sum(heart_train$thalach == "0")
print("Number of thalach Observations Equal to Zero")
thal_zero

chol_zero<-sum(heart_train$cholesterol == "0")
print("Number of cholesterol Observations Equal to Zero")
chol_zero
# Out:
# [1] "Number of rbp Observations Equal to Zero"
# [1] 0
# [1] "Number of thalach Observations Equal to Zero"
# [1] 0
# [1] "Number of cholesterol Observations Equal to Zero"
# [1] 0

# %% [markdown]
# The next step is calculating the mean, median and standard deviation of relevent variables and combining them into one data frame (Table 3)

# %%
age_par<-heart_train|>
summarize(mean = mean(age),
          med = median(age),
          sd = sd(age),
         variable="age")

rbp_par<-heart_train|>
summarize(mean = mean(rbp),
          med = median(rbp),
          sd = sd(rbp),
         variable="rbp")

chol_par<-heart_train|>
summarize(mean = mean(cholesterol),
          med = median(cholesterol),
          sd = sd(cholesterol),
         variable="cholesterol")

thal_par<-heart_train|>
summarize(mean = mean(thalach),
          med = median(thalach),
          sd = sd(thalach),
         variable="thalach")

heart_par<-rbind(age_par,rbp_par,chol_par,thal_par)
print("Table 3: Mean, Median and Standard Deviation of Relevant Variables")
heart_par
# Out:
# [1] "Table 3: Mean, Median and Standard Deviation of Relevant Variables"
#   mean     med sd       variable
# 1  53.3000  54  9.63681 age
# 2 132.5450 130 18.80720 rbp
# 3 239.4517 237 70.64660 cholesterol
# 4 138.3250 140 26.21007 thalach

# %%
#inspect thalach vs. disease

options(repr.plot.width = 15, repr.plot.height = 8)

thalach_dist <- ggplot(heart_train, aes(x = thalach, fill = factor(disease))) + 
                 geom_histogram(position = "dodge", bins=30) + 
                  labs(x = "Patient's Maximum Heart Rate (bpm)", y = "Number of Patients",fill = "Presence of Disease",
                       title = "Figure 1: Presence of Heart Disease vs. Patient's Max Heart Rate") + 
                  theme(text = element_text(size = 18))+
xlim(50, 220)



              

thalach_dist
# Out:
# Warning message:
# “Removed 1 rows containing non-finite values (stat_bin).”
# Warning message:
# “Removed 3 rows containing missing values (geom_bar).”
# plot without title

# %% [markdown]
# Figure 1 depicts the relationship between a patient's maximum heart rate and their risk of developing a heart disease. These two variables appear to be positively correlated, as the number of patients diagnosed with the condition increases as the patient's maxium heart rate gets larger. This indicated that individuals with a higher heart rate, specifically those above 100 bpm are at a much higher risk of developing the heart condition

# %%
options(repr.plot.width = 12, repr.plot.height = 8)

#inspect age vs. disease

options(repr.plot.width = 15, repr.plot.height = 8)
age_dist <- ggplot(heart_train, aes(x = age, fill=factor(disease)))+ 
                  geom_histogram(position = "dodge", bins=40) + 
                  labs(x = "Patient's Age (years)", y = "Number of Patients",fill = "Presence of Disease",title = "Figure 2: Presence of Heart Disease vs. Patient's Age") + 
                  theme(text = element_text(size = 18)) 


     

age_dist
# Out:
# plot without title

# %% [markdown]
# Figure 2 depicts the relationship between a age and the number of patients who developed the condition (true) or did not (false). These two variables appear to be somewhat positively correlated, as the number of patients diagnosed with the condition generally increases as the patient's age increases. This indicated that older individuals, specifically those between 55 and 70 years of age, are at a higher risk of developing the heart condition

# %%
#inspect source vs. disease

options(repr.plot.width = 12, repr.plot.height = 8)
source_dist <- ggplot(heart_train, aes(x = source, fill = disease)) + 
                  geom_histogram(position= "dodge",stat="count") + 
                  labs(x = "Data Source", y = "Number of Patients",fill = "Presence of Disease",title = "Figure 3: Presence of Heart Disease vs. Data Source") + 
                  theme(text = element_text(size = 18)) 
                  

source_dist
# Out:
# Warning message:
# “Ignoring unknown parameters: binwidth, bins, pad”
# plot without title

# %% [markdown]
# Figure 1 depicts the relationship between the source from which a patient's data originated and the risk of developing a heart disease. Cleveland and Hungary datasets appear to have much more data than the others, indicated by their taller bars. Additinally these two sources have more "false" predictions than they do "true" predictions. In comparison, The Switzerland and VA sources have the opposite relationship between number of "true" and "false" observations, and have much less data.

# %%
#visualize ratio of "true" and "false" observations


options(repr.plot.width = 12, repr.plot.height = 8)
disease_dist <- ggplot(heart_train, aes(x=disease,fill = disease)) + 
                  geom_bar() + 
                  labs( y = "Number of Observations",fill = "Presence of Disease",title = "Figure 4: Number of Observations Recorded for Disease") + 
                  theme(text = element_text(size = 18)) 

                  

disease_dist
# Out:
# plot without title

# %% [markdown]
# Figure 4 depicts the number of "true" and "false" observations recorded in the dataset. They appear to be relatively equal, which will allow for more accurate predictions to be made.

# %%
#add labels to sex collumn for visualization

sex_label<-heart_train

sex_label$sex <- factor(sex_label$sex ,
levels = c('0','1'),
labels = c("Female", "Male"))

#plot sex vs. disease
options(repr.plot.width = 12, repr.plot.height = 8)
sex_dist <- ggplot(sex_label, aes(x=sex, fill =disease)) + 
                  geom_bar(position= "dodge") + 
                  labs(y = "number of patients",fill = "presence of disease",
                       title = "Figure 5.1: Presence of heart disease vs. patient's sex") +
theme(text = element_text(size = 13))

    
#create dataframe with sex vs number of observations for each label

sex_num<-heart_train|>
count(sex)
sex_num$sex <- factor(sex_num$sex ,
levels = c('0','1'),
labels = c("Female", "Male"))

#plot sex vs number of observations for each label

options(repr.plot.width = 12, repr.plot.height = 8)
sex_prop<-ggplot(sex_num, aes(x=sex, y=n, fill=sex))+
                      geom_bar(stat = "identity", position = position_dodge())+
                 labs(x = "", y = "number of patients", fill= "Patient's Sex",
                      title = "Figure 5.2: Number of Target Observations for Each Sex")+
theme(text = element_text(size = 13),,axis.text.x = element_blank())

grid.arrange(sex_dist, sex_prop, ncol=2)
# Out:
# plot without title

# %% [markdown]
# Figure 5.1 depicts the number of "true" and "false" observations that correspond to each sex while figure 5.2 communicates the total number of target observations there are in the dataset for each sex.. From figure 5.2, we can see that there's an uneven ratio of "male" to "female" observations: There are approximately 450 "male" observations and 150 "female" observations. This trend evident in figure 5.1 as well. However, despite the inequal distrobution od sex observations, both sexes have a similar ratio of "true" and "false" observations.

# %%
options(repr.plot.width = 14, repr.plot.height = 6)

rbp_dist2 <-ggplot(heart_train,aes(x= rbp,color=disease))+
geom_line(aes(y=..count..),
          stat="bin",binwidth=1)+
   labs(x = "Patient Resting Blood Pressure (mmHg)", y = "Number of Patients",color = "Presence of Disease",
        title = "Figure 6.1: Presence of Heart Disease vs. Patient's Resting Blood Pressure ") + 
                  theme(text = element_text(size = 17))+
xlim(80, 200)

options(repr.plot.width = 12, repr.plot.height = 5)
rbp_dist <- ggplot(heart_train, aes(x= rbp, fill=disease)) + 
                  geom_histogram(position = "dodge", bins=30)+
                     labs(x = "Patient Resting Blood Pressure (mmHg)", y = "Number of Patients",color = "Presence of Disease",
        title = "Figure 6.2: Presence of Heart Disease vs. Patient's Resting Blood Pressure ") + 
                  theme(text = element_text(size = 17))+
xlim(75, 200)

rbp_dist2
rbp_dist
# Out:
# Warning message:
# “Removed 1 rows containing non-finite values (stat_bin).”
# Warning message:
# “Removed 1 rows containing non-finite values (stat_bin).”
# Warning message:
# “Removed 3 rows containing missing values (geom_bar).”
# plot without title
# plot without title

# %% [markdown]
# Figures 6.1 and 6.2 depict the relationship between a patients resting blood pressure and their risk of developping a heart disease. There is some correlation between the two variables and it appears that patients with a resting blood pressure between 120 and 135 are at a higher risk than the rest of the population.

# %%
options(repr.plot.width = 14, repr.plot.height = 6)


options(repr.plot.width = 12, repr.plot.height = 5)
chol_dist <- ggplot(heart_train, aes(x= cholesterol, fill=disease)) + 
                  geom_histogram(position = "dodge", bins=60)+
                     labs(x = "Cholesterol Level (mg/dl)", y = "Number of Patients",color = "Presence of Disease",
        title = "Figure 7: Presence of Heart Disease vs. Patient's Cholesterol") + 
                  theme(text = element_text(size = 17))+
xlim(80,450)


chol_dist
# Out:
# Warning message:
# “Removed 23 rows containing non-finite values (stat_bin).”
# Warning message:
# “Removed 3 rows containing missing values (geom_bar).”
# plot without title

# %% [markdown]
# Figure 7 displays the positive correlation between a patients cholesterol and their risk of developing a heart disease. As a patient's cholesteral increases, so does their risk of developing a heart disease.

# %%
#add labels for visualization purposes
heart_train2<-heart_train|>
mutate(type=as.factor(type))

heart_train2$type <- factor(heart_train2$type,
levels = c(1,2,3,4),
labels = c("typical angina","atypical angina","non-anginal pain","asymptomatic"))

#plot relationship

options(repr.plot.width = 12, repr.plot.height = 8)
type_dist <- ggplot(heart_train2, aes(x = type, fill = disease)) + 
                  geom_bar(position= "dodge") + 
                  labs(x = "Type of chest pain", y = "number of patients",fill = "presence of disease",
                       title = "Figure 8.1: Presence of Heart Disease vs. Type of Chest pain") + 
                  theme(text = element_text(size = 15)) 


#create dataframe with number of observations for each label

type_num<-heart_train2|>
count(type)
heart_train2$type <- factor(heart_train2$type,
levels = c(1,2,3,4),
labels = c("typical angina","atypical angina","non-anginal pain","asymptomatic"))

#plot type vs number of observations for each label

options(repr.plot.width = 12, repr.plot.height = 8)
type_prop<-ggplot(type_num, aes(x=type, y=n, fill=factor(type)))+
                      geom_bar(stat = "identity", position = position_dodge())+
                 labs(x = "", y = "number of patients", fill= "Type of Chest Pain",
                      title = "Figure 8.2: Number of Target Observations for Each Type of Chest Pain")+
theme(text = element_text(size = 15),axis.text.x = element_blank())

type_dist
type_prop
# Out:
# plot without title
# plot without title

# %% [markdown]
# Figures 8.1 depicts the number of "true" and "false" observations recorded under each type of chest pain while 8.2 shows the total number of observations recorded for each type. From 8.2, we can see that the data in unevely distributed amoungs the types as "asymptomatic" contains approximately half of all observations recorded. This is likely a factor in the distrobution of figure 8.1, where "asymptomatic" is the only type with more "false" observations than "true".

# %% [markdown]
# ## Predictive Analysis

# %% [markdown]
# To built the recipe, rank was selected as the target variable while the predicting variables were specified as age, sex, rbp, thalach, and type. The variables were scaled and centered to ensure that their mean was zero and their standard deviation was one. Without the standardization process, our predictors will have unequal effects on our classifier which would decrease the prediction accuracy of our model.

# %%
#creating recipe
recipe<- recipe(disease ~age+ sex+ rbp+thalach+type, data = heart_train) |>
step_scale(all_predictors())|>
    step_center(all_predictors())

# %% [markdown]
# Cross validation helps us choose the k-value to maximizes the prediction accuracy of our model. The 5-fold method randomly divides the training dataset into 5 evenly sized subsets of data. One of the subsets (or folds) is used for validation while the remaining 4 compose the training set. The process is repeated 5 times, using all subsets to calulate the accuracy of each K-value on each subset.

# %%
set.seed(4321)
#*Code Source: the following code was taken from " DSCI_100-Group-project" by Hannah Martin, and it was modified to suit this project (from * to *) 

# preform cross-validation
data_vfold <- vfold_cv(heart_train, v = 5, strata = disease)

#tune model and fit to workflow
knn_tune<- nearest_neighbor(weight_func ="rectangular", neighbors = tune()) |>
       set_engine("kknn") |>
       set_mode("classification")

#create data frame with K = [5, 10, 15, ... 100]
gridvals <- tibble(neighbors = seq(from = 5, to = 100, by = 5))
print("Table 4: Neighbors Used for Tuning the Model")
gridvals
# Out:
# [1] "Table 4: Neighbors Used for Tuning the Model"
#    neighbors
# 1    5
# 2   10
# 3   15
# 4   20
# 5   25
# 6   30
# 7   35
# 8   40
# 9   45
# 10  50
# 11  55
# 12  60
# 13  65
# 14  70
# 15  75
# 16  80
# 17  85
# 18  90
# 19  95
# 20 100

# %% [markdown]
# Seting the engine to "kknn" and the mode to "classification" specified the type of model we're building; K-nn classification. By setting the neighbors to "tune()" opposed to a specific number allows multiple k-values to be tested as once instead of just one. Our model tested every fifth value from 5-100 which provided a large range of K-values without drastically increasing the computation time.

# %% [markdown]
# The workflow is then used to combine the recipe, model specificaton, model tuning and to collect the metrics. The tune_grid function was used to determine the accuracies of our model (in addition to mean and standard deviation) while the collect_metrics function combines these values together. The mean value corresponds to the estimated model accuracy while the standard error measures the magnitute of uncertainty surrounding the mean.

# %%
set.seed(4321)

#collect tuning results

match_tune_res <- workflow() |>
                    add_recipe(recipe) |> 
                    add_model(knn_tune)|> 
                    tune_grid(resamples = data_vfold, grid = gridvals)|>
                    collect_metrics()

#plotting accuracy vs. number of neighbours

accuracies <- match_tune_res |>
    filter(.metric == "accuracy") |>
    arrange(desc(mean))
print("Table 5:Accuracy metrics arranged in descending order for various K-Values")
accuracies

accuracy_versus_k <- ggplot(accuracies, aes(x = neighbors, y = mean))+
    geom_point() +
    geom_line() +
    labs(x = "neighbors (K-values)", y = "accuracy estimate", title = "Figure 9: Model Accuracy vs. Number of Neighbors Used") +
    scale_x_continuous(breaks = seq(5, 100, by = 5)) +    
    theme(text = element_text(size = 20))
accuracy_versus_k
# Out:
# [1] "Table 5:Accuracy metrics arranged in descending order for various K-Values"
#    neighbors .metric  .estimator mean      n std_err    .config
# 1   30       accuracy binary     0.7781397 5 0.02355697 Preprocessor1_Model06
# 2   20       accuracy binary     0.7780977 5 0.02772407 Preprocessor1_Model04
# 3   25       accuracy binary     0.7714168 5 0.03030319 Preprocessor1_Model05
# 4   15       accuracy binary     0.7697919 5 0.02374014 Preprocessor1_Model03
# 5   10       accuracy binary     0.7681388 5 0.02785384 Preprocessor1_Model02
# 6   40       accuracy binary     0.7664445 5 0.02417218 Preprocessor1_Model08
# 7   35       accuracy binary     0.7647779 5 0.02401961 Preprocessor1_Model07
# 8   85       accuracy binary     0.7632637 5 0.02469854 Preprocessor1_Model17
# 9   60       accuracy binary     0.7632359 5 0.02567657 Preprocessor1_Model12
# 10  90       accuracy binary     0.7616110 5 0.02132348 Preprocessor1_Model18
# 11  65       accuracy binary     0.7615274 5 0.02607056 Preprocessor1_Model13
# 12 100       accuracy binary     0.7599859 5 0.01959942 Preprocessor1_Model20
# 13  95       accuracy binary     0.7599721 5 0.02017265 Preprocessor1_Model19
# 14  55       accuracy binary     0.7598745 5 0.02534590 Preprocessor1_Model11
# 15   5       accuracy binary     0.7582086 5 0.01643562 Preprocessor1_Model01
# 16  50       accuracy binary     0.7581661 5 0.02825982 Preprocessor1_Model10
# 17  80       accuracy binary     0.7565827 5 0.02525865 Preprocessor1_Model16
# 18  45       accuracy binary     0.7564854 5 0.02723542 Preprocessor1_Model09
# 19  70       accuracy binary     0.7548325 5 0.02659270 Preprocessor1_Model14
# 20  75       accuracy binary     0.7482072 5 0.02933306 Preprocessor1_Model15
# plot without title

# %% [markdown]
# To visualize how the model accuracy varies across the various K-values, the accuracy metrics obtained from tuning where graphed against the K-values. In general, the accuracy of our model increased as K got larger, with a peak occuring at K=30 .

# %% [markdown]
# ## Build Classification Model

# %% [markdown]
# Now that we know the most accurate K value, we can rebuild and retrain our model using k=30 in our workflow.

# %%
# Retrain model
best_model <- nearest_neighbor(weight_func = "rectangular", neighbors = 30)|>
                    set_engine("kknn")|>
                    set_mode("classification")

# Combine model in workflow
best_fit <- workflow()|>
            add_recipe(recipe) |>
            add_model(best_model) |>
            fit(data = heart_train)

# %%
# Make predictions
predict <- best_fit|> 
    predict(heart_test)|> 
    bind_cols(heart_test)

prediction_accuracy <- predict|>
    metrics(truth = disease, estimate = .pred_class)|> 
    filter(.metric == "accuracy")
print("Table 6: Prediction Accuracy for K-nn Classification with 30 Neighbours")
prediction_accuracy
# Out:
# [1] "Table 6: Prediction Accuracy for K-nn Classification with 30 Neighbours"
#   .metric  .estimator .estimate
# 1 accuracy binary     0.8059701

# %% [markdown]
# The fit and predict functions were used to predict testing set labels with our trained model. Then, the metrics function gave us a summary on the prediction accuracy of our model. The table returned by this function gave us an accuracy value of approximately 80.6%, meaning that our model is 80.6% accurate when predicting labels in the testing set. We can find more information on the predicted testing set labels by building a confusion matrix.

# %%
conf_matrix <- predict|>
    conf_mat(truth = disease, estimate = .pred_class)
print("Table 7: Confusion Matrix for K-nn classification with 30 Neighbours")
conf_matrix
# END CODE SOURCE*
# Out:
# [1] "Table 7: Confusion Matrix for K-nn classification with 30 Neighbours"
#           Truth
# Prediction false true
#      false    87   25
#      true     14   75

# %%
#Code Source: the following code was taken from " How to Create a Confusion Matrix in R" by Statology, and it was modified to suit this project
conf_plot<-autoplot(conf_matrix,type = "heatmap") +
  scale_fill_gradient(low = "cyan", high = "pink")
print("Figure 8: Visualization of Confusion Matrix for K-nn classification with 30 Neighbours")
conf_plot
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
# [1] "Figure 8: Visualization of Confusion Matrix for K-nn classification with 30 Neighbours"
# plot without title

# %% [markdown]
# ## Discussion

# %% [markdown]
# Using the metrics function, we found that the classification model (using k=30) was able to predict the class of an observation in the testing set correctly 80.6% of the time. The confusion matrix found that the model predicted 80.2% of the TRUE values in the testing set correctly, however only 73% of the TRUE observations were correct. Additionally, the model predicted 75.5% of the FALSE values in the testing set and 82.2% of the FALSE observations made were correct.
#
# Our model made a total of 201 predictions on the testing set, predicting “false” 110 times and “true” 91 times. This means that the model predicted “false” 54.7% of the time and “true” 45.3% of the time. While this correctly corresponds to the approximate ratio of false and true observations found in the training set, this result is not ideal considering the purpose of our model. Since the goal of our model is to allow for early diagnosis of heart conditions in individuals based on their personal and medical history, we want our model to be biased towards predicting “true” observations. If our model were to be used to help doctors know what patients are at risk, we would rather the model predict an observation as “true” when it’s actually “false” (predict that the patient has a disease when they actually dont) compared to predicting “false” when it’s actually “true” (predict that the patient has no disease when they actually do). If the model predicts that the patient has a disease when they actually don’t, there are few consequences of this false prediction. If the model predicts that the patient is disease free when they actually have a heart condition, this can have very extreme consequences since their condition could go untreated. In our preliminary data analysis, we found that the original dataset contained 403 “false” observations (50.3%) and 398 “true” observations (49.7%). Thus, we would want a minimum of 49.7% of our model predictions to be “true”. If this condition is met (or preferably exceeded) it could help indicate that our model is biased towards predicting “true”.
#
# The accuracy of our model could be impacted by a variety of factors such as the selected predictors. When building the model, we selected variables that we saw had logical connection to our target variable. We then tested and confirmed this correlation in our preliminary analysis. However, our interpretation of a logical connection may not be the same as our model’s. This means that we not have selected the most relevant predictors when building our model. One way to improve this would be by employing forward selection, which selects only the predictors that allow for the highest level of accuracy. Forward selection starts with a model that has no predictors, then it repeats the following steps until all available predictors are analyzed: Adds an unused predictor to the model, preforms cross validation on the model, updates the model by either adding or removing the predict
# or to maximize cross-validation accuracy.
#
# The impact of our project could be life-saving. It can reduce the time, effort, and resources that it takes to diagnose an individual with a heart condition just using data on their attributes. By further improving our model, we could make our predictions on the presence of heart conditions even more accurate, saving even more lives. This would allow medical practitioners as well as patients to take the necessary steps to protect their health as soon as possible. While our model can be applied to help identify the risk of heart disease in an individual, the concepts used can be applied to countless other conditions and situations. For example, the same strategy can be applied to datasets containing attributes from patients tested for brain tumors to predict an individual’s risk of developing a brain tumor. The same strategy and approach could be applied to countless other diagnosees and save countless lives through early diagnoses.Using the metrics function, we found that the classification model (using k=50) was able to predict the class of an observation in the testing set correctly 80.6% of the time. The confusion matrix found that the model predicted 80.2% of the TRUE values in the testing set correctly, however only 73% of the TRUE observations were correct. Additionally, the model predicted 75.5% of the FALSE values in the testing set and 82.2% of the FALSE obervations made were correct.

# %% [markdown]
# ## CITATIONS
#
# Bergström, G, et al. “The Swedish Cardiopulmonary Bioimage Study: Objectives and Design.” Journal of Internal Medicine, U.S. National Library of Medicine, 19 June 2015, www.ncbi.nlm.nih.gov/pmc/articles/PMC4744991/#:~:text=The%20Swedish%20CArdioPulmonary%20BioImage%20Study%20(SCAPIS)%20was%20initiated%20as%20a,important%20issues%20for%20public%20health.
#
# Canada, Public Health Agency of. “Government of Canada.” Canada.ca, Gouvernement Du Canada, 28 July 2022, www.canada.ca/en/public-health/services/publications/diseases-conditions/heart-disease-canada.html.
#
# “How to Create a Confusion Matrix in R (Step-by-Step).” Statology, 1 Apr. 2021, www.statology.org/confusion-matrix-in-r/.
# Janosi, Andras, et al. “ Heart Disease Data Set.” UCI Machine Learning Repository, 30 May 1989, archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/.
#
# Martin, Hannah. “DSCI_100-Group-Project/dsci_100_project.Ipynb at Main · Hmartin11/DSCI_100-Group-Project.” GitHub, github.com/hmartin11/DSCI_100-Group-Project/blob/main/DSCI_100_project.ipynb.
#
# Timbers, Tiffany, et al. “Data Science: A First Introduction.” 14 July 2022, doi:10.1201/9781003080978. 080978.
