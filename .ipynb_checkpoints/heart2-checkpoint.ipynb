# %%
#Load necessary packages
library(tidyverse)
library(testthat)
library(digest)
library(repr)
library(tidymodels)
library(ggplot2)
library("gridExtra")
library(GGally)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘testthat’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     matches
#
#
# The following object is masked from ‘package:purrr’:
#
#     is_null
#
#
# The following objects are masked from ‘package:readr’:
#
#     edition_get, local_edition
#
#
# The following object is masked from ‘package:tidyr’:
#
#     matches
#
#
# ── Attaching packages ────────────────────────────────────── tidymodels 1.0.0 ──
#
# ✔ broom        1.0.0     ✔ rsample      1.0.0
# ✔ dials        1.0.0     ✔ tune         1.0.0
# ✔ infer        1.0.2     ✔ workflows    1.0.0
# ✔ modeldata    1.0.0     ✔ workflowsets 1.0.0
# ✔ parsnip      1.0.0     ✔ yardstick    1.0.0
# ✔ recipes      1.0.1
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard()   masks purrr::discard()
# ✖ dplyr::filter()     masks stats::filter()
# ✖ recipes::fixed()    masks stringr::fixed()
# ✖ testthat::is_null() masks purrr::is_null()
# ✖ dplyr::lag()        masks stats::lag()
# ✖ rsample::matches()  masks testthat::matches(), dplyr::matches(), tidyr::matches()
# ✖ yardstick::spec()   masks readr::spec()
# ✖ recipes::step()     masks stats::step()
# • Use tidymodels_prefer() to resolve common conflicts.
#
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2

# %%
cleveland<-read_delim("https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data",
                col_name=FALSE)|>
mutate(source="cleveland")
colnames(cleveland)<-c("age","sex","type","rbp","cholesterol","fbs","rECG","max_hr","excr_ang","old_pk","slope","bv_color","thal","disease","source")

cleveland$disease<-ifelse(cleveland$disease==0, "true","false")

hungary<-read_delim("https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data",
                col_name = FALSE)|>
mutate(source="hungary")
colnames(hungary)<-c("age","sex","type","rbp","cholesterol","fbs","rECG","max_hr","excr_ang","old_pk","slope","bv_color","thal","disease","source")
hungary$disease<-ifelse(hungary$disease==0, "true","false")


va<-read_delim("https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.va.data",
                col_name=FALSE)|>
mutate(source="va")
colnames(va)<-c("age","sex","type","rbp","cholesterol","fbs","rECG","max_hr","excr_ang","old_pk","slope","bv_color","thal","disease","source")
va$disease<-ifelse(va$disease==0, "true","false")

#combine into one database

heart_data_OG<-rbind(va,hungary,cleveland)


heart_data_OG
# Out:
# Rows: 303 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (2): X12, X13
# dbl (12): X1, X2, X3, X4, X5, X6, X7, X8, X9, X10, X11, X14
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 294 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (9): X4, X5, X6, X7, X8, X9, X11, X12, X13
# dbl (5): X1, X2, X3, X10, X14
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 200 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (9): X4, X5, X6, X8, X9, X10, X11, X12, X13
# dbl (5): X1, X2, X3, X7, X14
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     age sex type rbp cholesterol fbs rECG max_hr excr_ang old_pk slope bv_color
# 1   63  1   4    140 260         0   1    112    1        3      2     ?
# 2   44  1   4    130 209         0   1    127    0        0      ?     ?
# 3   60  1   4    132 218         0   1    140    1        1.5    3     ?
# 4   55  1   4    142 228         0   1    149    1        2.5    1     ?
# 5   66  1   3    110 213         1   2    99     1        1.3    2     ?
# 6   66  1   3    120 0           0   1    120    0        -0.5   1     ?
# 7   65  1   4    150 236         1   1    105    1        0      ?     ?
# 8   60  1   3    180 0           0   1    140    1        1.5    2     ?
# 9   60  1   3    120 0           ?   0    141    1        2      1     ?
# 10  60  1   2    160 267         1   1    157    0        0.5    2     ?
# 11  56  1   2    126 166         0   1    140    0        0      ?     ?
# 12  59  1   4    140 0           0   1    117    1        1      2     ?
# 13  62  1   4    110 0           0   0    120    1        0.5    2     ?
# 14  63  1   3    ?   0           0   2    ?      ?        ?      ?     ?
# 15  57  1   4    128 0           1   1    148    1        1      2     ?
# 16  62  1   4    120 220         0   1    86     0        0      ?     ?
# 17  63  1   4    170 177         0   0    84     1        2.5    3     ?
# 18  46  1   4    110 236         0   0    125    1        2      2     ?
# 19  63  1   4    126 0           0   1    120    0        1.5    3     ?
# 20  60  1   4    152 0           0   1    118    1        0      ?     ?
# 21  58  1   4    116 0           0   0    124    0        1      1     ?
# 22  64  1   4    120 0           1   1    106    0        2      2     ?
# 23  63  1   3    130 0           0   1    111    1        0      ?     ?
# 24  74  1   3    ?   0           0   0    ?      ?        ?      ?     ?
# 25  52  1   3    128 0           0   1    180    0        3      1     ?
# 26  69  1   4    130 0           1   1    129    0        1      2     ?
# 27  51  1   4    ?   0           1   1    ?      ?        ?      ?     ?
# 28  60  1   4    130 186         1   1    140    1        0.5    2     ?
# 29  56  1   4    120 100         0   0    120    1        1.5    2     0
# 30  55  1   3    ?   228         0   1    ?      ?        ?      ?     ?
# ⋮   ⋮   ⋮   ⋮    ⋮   ⋮           ⋮   ⋮    ⋮      ⋮        ⋮      ⋮     ⋮
# 768 71  0   4    112 149         0   0    125    0        1.6    2     0.0
# 769 59  1   1    134 204         0   0    162    0        0.8    1     2.0
# 770 64  1   1    170 227         0   2    155    0        0.6    2     0.0
# 771 66  0   3    146 278         0   2    152    0        0      2     1.0
# 772 39  0   3    138 220         0   0    152    0        0      2     0.0
# 773 57  1   2    154 232         0   2    164    0        0      1     1.0
# 774 58  0   4    130 197         0   0    131    0        0.6    2     0.0
# 775 57  1   4    110 335         0   0    143    1        3      2     1.0
# 776 47  1   3    130 253         0   0    179    0        0      1     0.0
# 777 55  0   4    128 205         0   1    130    1        2      2     1.0
# 778 35  1   2    122 192         0   0    174    0        0      1     0.0
# 779 61  1   4    148 203         0   0    161    0        0      1     1.0
# 780 58  1   4    114 318         0   1    140    0        4.4    3     3.0
# 781 58  0   4    170 225         1   2    146    1        2.8    2     2.0
# 782 58  1   2    125 220         0   0    144    0        0.4    2     ?
# 783 56  1   2    130 221         0   2    163    0        0      1     0.0
# 784 56  1   2    120 240         0   0    169    0        0      3     0.0
# 785 67  1   3    152 212         0   2    150    0        0.8    2     0.0
# 786 55  0   2    132 342         0   0    166    0        1.2    1     0.0
# 787 44  1   4    120 169         0   0    144    1        2.8    3     0.0
# 788 63  1   4    140 187         0   2    144    1        4      1     2.0
# 789 63  0   4    124 197         0   0    136    1        0      2     0.0
# 790 41  1   2    120 157         0   0    182    0        0      1     0.0
# 791 59  1   4    164 176         1   2    90     0        1      2     2.0
# 792 57  0   4    140 241         0   0    123    1        0.2    2     0.0
# 793 45  1   1    110 264         0   0    132    0        1.2    2     0.0
# 794 68  1   4    144 193         1   0    141    0        3.4    2     2.0
# 795 57  1   4    130 131         0   0    115    1        1.2    2     1.0
# 796 57  0   2    130 236         0   2    174    0        0      2     1.0
# 797 38  1   3    138 175         0   0    173    0        0      1     ?
#     thal disease source
# 1   ?    false   va
# 2   ?    true    va
# 3   ?    false   va
# 4   ?    false   va
# 5   ?    true    va
# 6   ?    true    va
# 7   ?    false   va
# 8   ?    true    va
# 9   ?    false   va
# 10  ?    false   va
# 11  ?    true    va
# 12  ?    false   va
# 13  3    false   va
# 14  ?    false   va
# 15  ?    false   va
# 16  ?    true    va
# 17  ?    false   va
# 18  ?    false   va
# 19  ?    true    va
# 20  7    true    va
# 21  ?    false   va
# 22  ?    false   va
# 23  ?    false   va
# 24  ?    true    va
# 25  ?    false   va
# 26  6    false   va
# 27  ?    false   va
# 28  ?    false   va
# 29  7    false   va
# 30  ?    false   va
# ⋮   ⋮    ⋮       ⋮
# 768 3.0  true    cleveland
# 769 3.0  false   cleveland
# 770 7.0  true    cleveland
# 771 3.0  true    cleveland
# 772 3.0  true    cleveland
# 773 3.0  false   cleveland
# 774 3.0  true    cleveland
# 775 7.0  false   cleveland
# 776 3.0  true    cleveland
# 777 7.0  false   cleveland
# 778 3.0  true    cleveland
# 779 7.0  false   cleveland
# 780 6.0  false   cleveland
# 781 6.0  false   cleveland
# 782 7.0  true    cleveland
# 783 7.0  true    cleveland
# 784 3.0  true    cleveland
# 785 7.0  false   cleveland
# 786 3.0  true    cleveland
# 787 6.0  false   cleveland
# 788 7.0  false   cleveland
# 789 3.0  false   cleveland
# 790 3.0  true    cleveland
# 791 6.0  false   cleveland
# 792 7.0  false   cleveland
# 793 7.0  false   cleveland
# 794 7.0  false   cleveland
# 795 7.0  false   cleveland
# 796 3.0  false   cleveland
# 797 3.0  true    cleveland

# %%
#tidy data
heart_data<-heart_data_OG|>
select(source, disease, age, sex, rbp,type, cholesterol)|>
filter(type!="?", sex!="?", rbp!="?", cholesterol!="NA",cholesterol!="0",rbp!="0")|>
mutate(sex=as.numeric(sex),
      rbp=as.numeric(rbp),
      type=as.factor(type),
       disease=as.factor(disease),
      cholesterol=as.numeric(cholesterol))|>
na.omit(heart_data)



heart_data$type <- factor(heart_data$type,
levels = c('1','2','3','4'),
labels = c("typical angina", "atypical angina","non-anginal","asymptomatic"))
heart_data
# Out:
# Warning message in mask$eval_all_mutate(quo):
# “NAs introduced by coercion”
#     source    disease age sex rbp type            cholesterol
# 1   va        false   63  1   140 asymptomatic    260
# 2   va        true    44  1   130 asymptomatic    209
# 3   va        false   60  1   132 asymptomatic    218
# 4   va        false   55  1   142 asymptomatic    228
# 5   va        true    66  1   110 non-anginal     213
# 6   va        false   65  1   150 asymptomatic    236
# 7   va        false   60  1   160 atypical angina 267
# 8   va        true    56  1   126 atypical angina 166
# 9   va        true    62  1   120 asymptomatic    220
# 10  va        false   63  1   170 asymptomatic    177
# 11  va        false   46  1   110 asymptomatic    236
# 12  va        false   60  1   130 asymptomatic    186
# 13  va        false   56  1   120 asymptomatic    100
# 14  va        false   77  1   124 asymptomatic    171
# 15  va        false   63  1   160 asymptomatic    230
# 16  va        false   59  1   122 asymptomatic    233
# 17  va        true    42  1   134 non-anginal     240
# 18  va        false   62  1   152 asymptomatic    153
# 19  va        true    56  1   124 atypical angina 224
# 20  va        false   57  1   130 asymptomatic    311
# 21  va        false   67  1   142 typical angina  270
# 22  va        true    55  1   110 atypical angina 214
# 23  va        false   57  1   140 asymptomatic    214
# 24  va        false   54  1   136 asymptomatic    220
# 25  va        false   72  1   120 non-anginal     214
# 26  va        false   75  1   170 asymptomatic    203
# 27  va        false   60  1   142 asymptomatic    216
# 28  va        false   64  0   142 asymptomatic    276
# 29  va        true    58  1   132 asymptomatic    458
# 30  va        false   61  1   146 asymptomatic    241
# ⋮   ⋮         ⋮       ⋮   ⋮   ⋮   ⋮               ⋮
# 646 cleveland true    71  0   112 asymptomatic    149
# 647 cleveland false   59  1   134 typical angina  204
# 648 cleveland true    64  1   170 typical angina  227
# 649 cleveland true    66  0   146 non-anginal     278
# 650 cleveland true    39  0   138 non-anginal     220
# 651 cleveland false   57  1   154 atypical angina 232
# 652 cleveland true    58  0   130 asymptomatic    197
# 653 cleveland false   57  1   110 asymptomatic    335
# 654 cleveland true    47  1   130 non-anginal     253
# 655 cleveland false   55  0   128 asymptomatic    205
# 656 cleveland true    35  1   122 atypical angina 192
# 657 cleveland false   61  1   148 asymptomatic    203
# 658 cleveland false   58  1   114 asymptomatic    318
# 659 cleveland false   58  0   170 asymptomatic    225
# 660 cleveland true    58  1   125 atypical angina 220
# 661 cleveland true    56  1   130 atypical angina 221
# 662 cleveland true    56  1   120 atypical angina 240
# 663 cleveland false   67  1   152 non-anginal     212
# 664 cleveland true    55  0   132 atypical angina 342
# 665 cleveland false   44  1   120 asymptomatic    169
# 666 cleveland false   63  1   140 asymptomatic    187
# 667 cleveland false   63  0   124 asymptomatic    197
# 668 cleveland true    41  1   120 atypical angina 157
# 669 cleveland false   59  1   164 asymptomatic    176
# 670 cleveland false   57  0   140 asymptomatic    241
# 671 cleveland false   45  1   110 typical angina  264
# 672 cleveland false   68  1   144 asymptomatic    193
# 673 cleveland false   57  1   130 asymptomatic    131
# 674 cleveland false   57  0   130 atypical angina 236
# 675 cleveland true    38  1   138 non-anginal     175

# %%
#Split the data
set.seed(4321) 
heart_splt <- initial_split(heart_data, prop = 0.70
                           , strata =disease)
heart_train <- training(heart_splt)
heart_test<- testing(heart_splt)

# %% [markdown]
# ##preliminary data analysis

# %%
# Check if there are any rows with missing data
print("Table 1: Number of Rows with Missing Data for the Predictor and Classifier Variables")
heart_missing <- map_df(heart_train, ~sum(is.na(.)))
heart_missing
# Out:
# [1] "Table 1: Number of Rows with Missing Data for the Predictor and Classifier Variables"
#   source disease age sex rbp type cholesterol
# 1 0      0       0   0   0   0    0

# %%
sex_dist <- ggplot(heart_train, aes(x = sex, fill = disease)) + 
                  geom_bar(position="dodge") + 
                  labs(x = "Patient's Sex", y = "number of patients",fill = "presence of disease",title = "Figure 2: Presence of heart disease vs. patient's sex") + 
                  theme(text = element_text(size = 18)) 
                  

sex_dist
# Out:
# plot without title

# %%
options(repr.plot.width = 12, repr.plot.height = 8)
age_dist <- ggplot(heart_train, aes(x = age, fill = disease)) + 
                  geom_bar(position= "dodge") + 
                  labs(x = "Patient's age", y = "number of patients",fill = "presence of disease",title = "Figure 2: Presence of heart disease vs. patient's age") + 
                  theme(text = element_text(size = 18)) 
                  

age_dist
# Out:
# plot without title

# %%
options(repr.plot.width = 12, repr.plot.height = 8)
source_dist <- ggplot(heart_train, aes(x = source, fill = disease)) + 
                  geom_bar(position= "dodge") + 
                  labs(x = "Patient's Sex", y = "number of patients",fill = "presence of disease",title = "Figure 2: Presence of heart disease vs. data source") + 
                  theme(text = element_text(size = 18)) 
                  

source_dist
# Out:
# plot without title

# %%
options(repr.plot.width = 12, repr.plot.height = 8)
disease_dist <- ggplot(heart_train, aes(x=disease,fill = disease)) + 
                  geom_bar() + 
                  labs( y = "count",fill = "presence of disease",title = "number of observations recorded") + 
                  theme(text = element_text(size = 18)) 
                  

disease_dist
# Out:
# plot without title

# %%
options(repr.plot.width = 12, repr.plot.height = 8)
sex_dist <- ggplot(heart_train, aes(x=sex, fill = disease)) + 
                  geom_bar(position= "dodge") + 
                  labs(x = "Patient's Sex", y = "number of patients",fill = "presence of disease",title = "Figure 2: Presence of heart disease vs. patient's sex") + 
                  theme(text = element_text(size = 18)) 
                  




sex_count <- ggplot(heart_train, aes(x=sex,fill = sex, color=sex)) + 
                  geom_histogram(position= "dodge",bins=2, binwidth=0.6) + 
                  labs(x = "Patient's Sex", y = "number of patients",fill = "presence of disease",title = "Figure 2: Presence of heart disease vs. patient's sex") + 
                  theme(text = element_text(size = 18)) 
grid.arrange(sex_dist, sex_count, ncol=2)
# Out:
# plot without title

# %%
options(repr.plot.width = 12, repr.plot.height = 8)
rbp_dist <- ggplot(heart_train, aes(x= rbp, fill=disease)) + 
                  geom_bar()+
                  labs(x = "Patient's Sex", y = "number of patients",fill = "presence of disease",title = "Figure 2: Presence of heart disease vs. patient's sex") + 
                  theme(text = element_text(size = 20)) 
rbp_dist
# Out:
# plot without title

# %%
options(repr.plot.width = 12, repr.plot.height = 8)
chol_dist <- ggplot(heart_train, aes(x= age, y=cholesterol, color=disease)) + 
                  geom_point()+
                  labs(x = "Patient's Sex", y = "number of patients",fill = "presence of disease",title = "Figure 2: Presence of heart disease vs. patient's sex") + 
                  theme(text = element_text(size = 20)) 
chol_dist
# Out:
# plot without title

# %%
##predictive analysis

# %%
#creating recipe
recipe<- recipe(disease ~age+ sex+ rbp, data = heart_train) |>
step_scale(all_predictors())|>
    step_center(all_predictors())

# %% [markdown]
# To built the recipe, rank was selected as the target variable while the predicting variables were specified as aces, rank points, age and draw size. The variables were scaled and centered to ensure that their mean was zero and their standard deviation was one.Since our dataset is fairly large and would take too long to run cross validation on the entire training set, we took a smaller random sample from the training set to run cross validation on. Since the sample is random, it should be representative of the whole trainig set.

# %% [markdown]
# Cross validation helps us choose the k-value to maximizes the prediction accuracy of our model. The 5-fold method randomly divides the training dataset into 5 evenly sized subsets of data. One of the subsets (or folds) is used for validation while the remaining 4 compose the training set. The process is repeated 5 times, using all subsets to calulate the accuracy of each K-value on each subset.

# %%
set.seed(4321)
#Code Source: the following code was taken from " DSCI_100-Group-project" by Hannah Martin, and it was modified to suit this project 

# preform cross-validation
data_vfold <- vfold_cv(heart_train, v = 5, strata = disease)
#tune model and fit to workflow
knn_tune<- nearest_neighbor(weight_func ="rectangular", neighbors = tune()) |>
       set_engine("kknn") |>
       set_mode("classification")

#create data frame with K = [5, 10, 15, ... 100]
gridvals <- tibble(neighbors = seq(from = 5, to = 100, by = 5))
print("Table 1: Neighbors Used for Tuning the Model")
gridvals
# Out:
# [1] "Table 1: Neighbors Used for Tuning the Model"
#    neighbors
# 1    5
# 2   10
# 3   15
# 4   20
# 5   25
# 6   30
# 7   35
# 8   40
# 9   45
# 10  50
# 11  55
# 12  60
# 13  65
# 14  70
# 15  75
# 16  80
# 17  85
# 18  90
# 19  95
# 20 100

# %% [markdown]
# Seting the engine to "kknn" and the mode to "classification" specified the type of model we're building; K-nn classification. By setting the neighbors to "tune()" opposed to a specific number allows multiple k-values to be tested as once instead of just one. Our model tested every fifth value from 0-100 which provided a large range of K-values without drastically increasing the computation time.

# %% [markdown]
# The workflow is used to combine the recipe, model specificaton, model tuning and to collect the metrics. The tune_grid function was used to determine the accuracies of our model (in addition to mean and standard deviation) while the collect_metrics function collected these values together. The mean value corresponds to the estimated model accuracy while the standard error measures the magnitute of uncertainty surrounding the mean,.

# %%
#Code Source: the following code was taken from " DSCI_100-Group-project" by Hannah Martin, and it was modified to suit this project 

set.seed(4321)

#collect tuning results

match_tune_res <- workflow() |>
                    add_recipe(recipe) |> 
                    add_model(knn_tune)|> 
                    tune_grid(resamples = data_vfold, grid = gridvals)|>
                    collect_metrics()

#plotting accuracy vs. number of neighbours

accuracies <- match_tune_res |>
    filter(.metric == "accuracy") |>
    arrange(desc(mean))
print("Accuracy metrics arranged in descending order for various K-Values")
accuracies

accuracy_versus_k <- ggplot(accuracies, aes(x = neighbors, y = mean))+
    geom_point() +
    geom_line() +
    labs(x = "neighbors (K-values)", y = "accuracy estimate", title = "model accuracy vs. number of neighbors used") +
    scale_x_continuous(breaks = seq(5, 100, by = 5)) +    
    theme(text = element_text(size = 20))
accuracy_versus_k
# Out:
# [1] "Accuracy metrics arranged in descending order for various K-Values"
#    neighbors .metric  .estimator mean      n std_err     .config
# 1   50       accuracy binary     0.6780151 5 0.011888557 Preprocessor1_Model10
# 2   65       accuracy binary     0.6758646 5 0.012088074 Preprocessor1_Model13
# 3   70       accuracy binary     0.6758646 5 0.008924099 Preprocessor1_Model14
# 4   55       accuracy binary     0.6737150 5 0.013146378 Preprocessor1_Model11
# 5   40       accuracy binary     0.6715864 5 0.015318343 Preprocessor1_Model08
# 6   80       accuracy binary     0.6695035 5 0.005822542 Preprocessor1_Model16
# 7   90       accuracy binary     0.6673306 5 0.007494067 Preprocessor1_Model18
# 8   75       accuracy binary     0.6673082 5 0.006987200 Preprocessor1_Model15
# 9   85       accuracy binary     0.6673082 5 0.009651026 Preprocessor1_Model17
# 10  60       accuracy binary     0.6652258 5 0.014072136 Preprocessor1_Model12
# 11  45       accuracy binary     0.6651806 5 0.010290609 Preprocessor1_Model09
# 12 100       accuracy binary     0.6631201 5 0.007030878 Preprocessor1_Model20
# 13  20       accuracy binary     0.6611063 5 0.019370728 Preprocessor1_Model04
# 14  35       accuracy binary     0.6610377 5 0.015075829 Preprocessor1_Model07
# 15  95       accuracy binary     0.6610148 5 0.008717009 Preprocessor1_Model19
# 16  30       accuracy binary     0.6544960 5 0.016689218 Preprocessor1_Model06
# 17  25       accuracy binary     0.6504437 5 0.007063025 Preprocessor1_Model05
# 18  15       accuracy binary     0.6440379 5 0.014083067 Preprocessor1_Model03
# 19   5       accuracy binary     0.6356168 5 0.014135835 Preprocessor1_Model01
# 20  10       accuracy binary     0.6227812 5 0.010653396 Preprocessor1_Model02
# plot without title

# %% [markdown]
# To visualize how the model accuracy varies across the various K-values, the accuracy metrics obtained from tuning where graphed against the K-values. In general, the accuracy of our model increased as K got larger, with a peak occuring at K=50 .Now that we know the most accurate K value, we can rebuild and retrain our model using k=50in our workflow.

# %%
# Retrain model
best_model <- nearest_neighbor(weight_func = "rectangular", neighbors = 50)|>
                    set_engine("kknn")|>
                    set_mode("classification")

# Combine model in workflow
best_fit <- workflow()|>
            add_recipe(recipe) |>
            add_model(best_model) |>
            fit(data = heart_train)

# %%
# Make predictions
predict <- best_fit|> 
    predict(heart_test)|> 
    bind_cols(heart_test)

prediction_accuracy <- predict|>
    metrics(truth = disease, estimate = .pred_class)|> 
    filter(.metric == "accuracy")
print("Table 6: Prediction Accuracy for K-nn classification with 50 Neighbours")
prediction_accuracy
# Out:
# [1] "Table 6: Prediction Accuracy for K-nn classification with 50 Neighbours"
#   .metric  .estimator .estimate
# 1 accuracy binary     0.6699507

# %% [markdown]
# The fit and predict functions were used to predict testing set labels with our trained model. Then, the metrics function gave us a summary on the prediction accuracy of our model. The table returned by this function gave us an accuracy value of approximately 67%, meaning that our model is 67% accurate when predicting labels in the testing set. We can find more information on the predicted testing set labels by building a confusion matrix.

# %%
conf_matrix <- predict|>
    conf_mat(truth = disease, estimate = .pred_class)
print("Table 7: Confusion Matrix for K-nn classification with 50 Neighbours")
conf_matrix
# Out:
# [1] "Table 7: Confusion Matrix for K-nn classification with 50 Neighbours"
#           Truth
# Prediction false true
#      false    76   47
#      true     20   60

# %% [markdown]
# ##discussion

# %% [markdown]
# Using the metrics function, we found that the classification model (using k=50) was able to predict the class of an observation in the testing set correctly 66.995% of the time. The confusion matrix found that the model predicted 75% of the TRUE values in the testing set correctly, however only 56% of the TRUE observations were correct. Additionally, the model predicted 92% of the FALSE values in the testing set and 96% of the FALSE obervations made were correct.
